# %% [markdown]
# # 25 Pandas Tricks

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <h4>1 - Show pandas version</h4>

# %%
pd.__version__
# Out:
# '0.22.0'

# %%
# to show pandas dependencies version
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit: None
# python: 3.6.4.final.0
# python-bits: 64
# OS: Windows
# OS-release: 8.1
# machine: AMD64
# processor: Intel64 Family 6 Model 94 Stepping 3, GenuineIntel
# byteorder: little
# LC_ALL: None
# LANG: None
# LOCALE: None.None
#
# pandas: 0.22.0
# pytest: 3.3.2
# pip: 19.1
# setuptools: 38.4.0
# Cython: 0.27.3
# numpy: 1.16.3
# scipy: 1.0.0
# pyarrow: None
# xarray: None
# IPython: 6.2.1
# sphinx: 1.6.6
# patsy: 0.5.0
# dateutil: 2.6.1
# pytz: 2017.3
# blosc: None
# bottleneck: 1.2.1
# tables: 3.4.2
# numexpr: 2.6.4
# feather: None
# matplotlib: 2.1.2
# openpyxl: 2.4.10
# xlrd: 1.1.0
# xlwt: 1.3.0
# xlsxwriter: 1.0.2
# lxml: 4.1.1
# bs4: 4.6.0
# html5lib: 0.9999999
# sqlalchemy: 1.2.1
# pymysql: None
# psycopg2: None
# jinja2: 2.10
# s3fs: None
# fastparquet: None
# pandas_gbq: None
# pandas_datareader: 0.6.0

# %% [markdown]
# <h4>2 - Create example Dataframe</h4>

# %%
# 1st approach
df = pd.DataFrame({'col_1': [1, 2], 'col_2': [3, 4]})

# %%
df
# Out:
#    col_1  col_2
# 0      1      3
# 1      2      4

# %%
# 2nd approach
df = pd.DataFrame(np.random.rand(4, 8))

# %%
df
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.167255  0.309563  0.726674  0.027462  0.397916  0.011975  0.721583
# 1  0.404984  0.976841  0.801875  0.387022  0.290129  0.453034  0.996532
# 2  0.775633  0.268406  0.722867  0.183203  0.295927  0.571763  0.692545
# 3  0.798204  0.191955  0.787879  0.626682  0.419772  0.900318  0.702987
#
#           7
# 0  0.554896
# 1  0.539585
# 2  0.514515
# 3  0.605278

# %%
# 3rd appraoch to get rid of numeric column names
df = pd.DataFrame(np.random.rand(4, 8), columns=list('abcdefgh'))

# %%
df
# Out:
#           a         b         c         d         e         f         g  \
# 0  0.776078  0.983917  0.079073  0.772274  0.871710  0.946796  0.164049
# 1  0.619791  0.812619  0.372781  0.828590  0.656757  0.629156  0.645358
# 2  0.984769  0.172370  0.592242  0.260396  0.025028  0.097490  0.300470
# 3  0.281940  0.872758  0.353650  0.462969  0.766828  0.545482  0.497650
#
#           h
# 0  0.318552
# 1  0.382333
# 2  0.825898
# 3  0.586664

# %% [markdown]
# <h4>3 - Rename columns</h4>

# %%
df = pd.DataFrame(np.random.rand(4, 2), columns=['col 1', 'col 2'])

# %%
df
# Out:
#       col 1     col 2
# 0  0.145441  0.728195
# 1  0.775665  0.521138
# 2  0.104177  0.256863
# 3  0.168555  0.256248

# %%
# remove space within column names
# 1st approach
df1 = df.rename({'col 1': 'col_1', 'col 2': 'col_2'}, axis='columns')

# %%
df1
# Out:
#       col_1     col_2
# 0  0.145441  0.728195
# 1  0.775665  0.521138
# 2  0.104177  0.256863
# 3  0.168555  0.256248

# %%
# 2nd approach
df.columns = df.columns.str.replace(' ', '_')

# %%
df
# Out:
#       col_1     col_2
# 0  0.145441  0.728195
# 1  0.775665  0.521138
# 2  0.104177  0.256863
# 3  0.168555  0.256248

# %%
# 3rd approach, by overriding column values
df = pd.DataFrame(np.random.rand(4, 2), columns=['col 1', 'col 2'])

# %%
df
# Out:
#       col 1     col 2
# 0  0.074903  0.265241
# 1  0.391024  0.164798
# 2  0.770211  0.219412
# 3  0.738951  0.097071

# %%
df.columns = ['col_1', 'col_2']

# %%
df
# Out:
#       col_1     col_2
# 0  0.074903  0.265241
# 1  0.391024  0.164798
# 2  0.770211  0.219412
# 3  0.738951  0.097071

# %%
# to add prefix or suffix
df.add_prefix('X_')
# Out:
#     X_col_1   X_col_2
# 0  0.074903  0.265241
# 1  0.391024  0.164798
# 2  0.770211  0.219412
# 3  0.738951  0.097071

# %%
df.add_suffix('_Y')
# Out:
#     col_1_Y   col_2_Y
# 0  0.074903  0.265241
# 1  0.391024  0.164798
# 2  0.770211  0.219412
# 3  0.738951  0.097071

# %% [markdown]
# <h4>4 - Reverse Row Order</h4>

# %%
df = pd.read_csv('http://bit.ly/drinksbycountry')

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
# reverse row order
df.loc[::-1].head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 192   Zimbabwe             64               18              4
# 191     Zambia             32               19              4
# 190      Yemen              6                0              0
# 189    Vietnam            111                2              1
# 188  Venezuela            333              100              3
#
#      total_litres_of_pure_alcohol      continent
# 192                           4.7         Africa
# 191                           2.5         Africa
# 190                           0.1           Asia
# 189                           2.0           Asia
# 188                           7.7  South America

# %%
# reset index and remove old one
df.loc[::-1, :].reset_index(drop=True)
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0                Zimbabwe             64               18              4
# 1                  Zambia             32               19              4
# 2                   Yemen              6                0              0
# 3                 Vietnam            111                2              1
# 4               Venezuela            333              100              3
# 5                 Vanuatu             21               18             11
# 6              Uzbekistan             25              101              8
# 7                 Uruguay            115               35            220
# 8                     USA            249              158             84
# 9                Tanzania             36                6              1
# 10         United Kingdom            219              126            195
# 11   United Arab Emirates             16              135              5
# 12                Ukraine            206              237             45
# 13                 Uganda             45                9              0
# 14                 Tuvalu              6               41              9
# 15           Turkmenistan             19               71             32
# 16                 Turkey             51               22              7
# 17                Tunisia             51                3             20
# 18      Trinidad & Tobago            197              156              7
# 19                  Tonga             36               21              5
# 20                   Togo             36                2             19
# 21            Timor-Leste              1                1              4
# 22              Macedonia            106               27             86
# 23               Thailand             99              258              1
# 24             Tajikistan              2               15              0
# 25                  Syria              5               35             16
# 26            Switzerland            185              100            280
# 27                 Sweden            152               60            186
# 28              Swaziland             90                2              2
# 29               Suriname            128              178              7
# ..                    ...            ...              ...            ...
# 163            Cabo Verde            144               56             16
# 164         Cote d'Ivoire             37                1              7
# 165               Burundi             88                0              0
# 166          Burkina Faso             25                7              7
# 167              Bulgaria            231              252             94
# 168                Brunei             31                2              1
# 169                Brazil            245              145             16
# 170              Botswana            173               35             35
# 171    Bosnia-Herzegovina             76              173              8
# 172               Bolivia            167               41              8
# 173                Bhutan             23                0              0
# 174                 Benin             34                4             13
# 175                Belize            263              114              8
# 176               Belgium            295               84            212
# 177               Belarus            142              373             42
# 178              Barbados            143              173             36
# 179            Bangladesh              0                0              0
# 180               Bahrain             42               63              7
# 181               Bahamas            122              176             51
# 182            Azerbaijan             21               46              5
# 183               Austria            279               75            191
# 184             Australia            261               72            212
# 185               Armenia             21              179             11
# 186             Argentina            193               25            221
# 187     Antigua & Barbuda            102              128             45
# 188                Angola            217               57             45
# 189               Andorra            245              138            312
# 190               Algeria             25                0             14
# 191               Albania             89              132             54
# 192           Afghanistan              0                0              0
#
#      total_litres_of_pure_alcohol      continent
# 0                             4.7         Africa
# 1                             2.5         Africa
# 2                             0.1           Asia
# 3                             2.0           Asia
# 4                             7.7  South America
# 5                             0.9        Oceania
# 6                             2.4           Asia
# 7                             6.6  South America
# 8                             8.7  North America
# 9                             5.7         Africa
# 10                           10.4         Europe
# 11                            2.8           Asia
# 12                            8.9         Europe
# 13                            8.3         Africa
# 14                            1.0        Oceania
# 15                            2.2           Asia
# 16                            1.4           Asia
# 17                            1.3         Africa
# 18                            6.4  North America
# 19                            1.1        Oceania
# 20                            1.3         Africa
# 21                            0.1           Asia
# 22                            3.9         Europe
# 23                            6.4           Asia
# 24                            0.3           Asia
# 25                            1.0           Asia
# 26                           10.2         Europe
# 27                            7.2         Europe
# 28                            4.7         Africa
# 29                            5.6  South America
# ..                            ...            ...
# 163                           4.0         Africa
# 164                           4.0         Africa
# 165                           6.3         Africa
# 166                           4.3         Africa
# 167                          10.3         Europe
# 168                           0.6           Asia
# 169                           7.2  South America
# 170                           5.4         Africa
# 171                           4.6         Europe
# 172                           3.8  South America
# 173                           0.4           Asia
# 174                           1.1         Africa
# 175                           6.8  North America
# 176                          10.5         Europe
# 177                          14.4         Europe
# 178                           6.3  North America
# 179                           0.0           Asia
# 180                           2.0           Asia
# 181                           6.3  North America
# 182                           1.3         Europe
# 183                           9.7         Europe
# 184                          10.4        Oceania
# 185                           3.8         Europe
# 186                           8.3  South America
# 187                           4.9  North America
# 188                           5.9         Africa
# 189                          12.4         Europe
# 190                           0.7         Africa
# 191                           4.9         Europe
# 192                           0.0           Asia
#
# [193 rows x 6 columns]

# %% [markdown]
# <h4>5 - Reverse Column Order</h4>

# %%
df.loc[:, ::-1].head()
# Out:
#   continent  total_litres_of_pure_alcohol  wine_servings  spirit_servings  \
# 0      Asia                           0.0              0                0
# 1    Europe                           4.9             54              132
# 2    Africa                           0.7             14                0
# 3    Europe                          12.4            312              138
# 4    Africa                           5.9             45               57
#
#    beer_servings      country
# 0              0  Afghanistan
# 1             89      Albania
# 2             25      Algeria
# 3            245      Andorra
# 4            217       Angola

# %% [markdown]
# <h4>6 - Select Columns by Data Type</h4>

# %%
drinks = pd.read_csv("http://bit.ly/drinksbycountry")

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks.select_dtypes(include='number').head()
# Out:
#    beer_servings  spirit_servings  wine_servings  total_litres_of_pure_alcohol
# 0              0                0              0                           0.0
# 1             89              132             54                           4.9
# 2             25                0             14                           0.7
# 3            245              138            312                          12.4
# 4            217               57             45                           5.9

# %%
drinks.select_dtypes(include='object').head()
# Out:
#        country continent
# 0  Afghanistan      Asia
# 1      Albania    Europe
# 2      Algeria    Africa
# 3      Andorra    Europe
# 4       Angola    Africa

# %%
drinks.select_dtypes(include=['number', 'object']).head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.select_dtypes(exclude='number').head()
# Out:
#        country continent
# 0  Afghanistan      Asia
# 1      Albania    Europe
# 2      Algeria    Africa
# 3      Andorra    Europe
# 4       Angola    Africa

# %% [markdown]
# <h4>7 - Convert Strings to Numeric</h4>

# %%
df = pd.DataFrame({'col 1': ['1.2', '3.2'],
                  'col 2': ['4.5', '5.4'],
                  'col 3': ['5.4', '-']})

# %%
df
# Out:
#   col 1 col 2 col 3
# 0   1.2   4.5   5.4
# 1   3.2   5.4     -

# %%
df.dtypes
# Out:
# col 1    object
# col 2    object
# col 3    object
# dtype: object

# %%
df.astype({'col 1': 'float', 'col 2': 'float'}).dtypes
# Out:
# col 1    float64
# col 2    float64
# col 3     object
# dtype: object

# %%
# col 3 contains '-', that's why we can't convert it directly into numeric data type
pd.to_numeric(df['col 3'], errors='coerec').fillna(0)
# Out:
# 0    5.4
# 1    0.0
# Name: col 3, dtype: float64

# %%
df = df.apply(pd.to_numeric, errors='coerce').fillna(0)

# %%
df.dtypes
# Out:
# col 1    float64
# col 2    float64
# col 3    float64
# dtype: object

# %%
df
# Out:
#    col 1  col 2  col 3
# 0    1.2    4.5    5.4
# 1    3.2    5.4    0.0
